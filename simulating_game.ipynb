# %% [markdown]
# ### Initial Setup

# %%
# importing libraries
from mcts import *
import gui
import time

# %%
# setting up neural network
nn1 = Neural_Network(
    input_layer_num_nodes=84,
    hidden_layer_dimensions=[84, 84],
    output_layer_dimensions=[7, 1],
    alias='Horizons Neural Network',
    activation_functions=[relu, relu, softmax, tanh],
    weight_normalizations=[he_normal, he_normal, xavier_normal, xavier_normal]
)

# %%
# initializing the tree
tree_1 = MCTS_Tree(
    root_history=[],
    neural_network=nn1
)

# %%
game_history = []
max_iterations = 200
max_depth = 6
exploration_constant = 3

# %% [markdown]
# ### Simulate Full Game

# %%
curr_turn = 1
curr_player = 'Red'


print('='*50)
while(tree_1.curr_root_node.game_state.game_over == False):
    start_time = time.perf_counter()
    move_chosen = tree_1.make_move(
        max_iterations=max_iterations,
        max_depth=max_depth,
        exploration_constant=exploration_constant
    )
    end_time = time.perf_counter()
    print(f'Turn #{curr_turn} | {curr_player} ==> Move {move_chosen} [{round(end_time - start_time, 3)}s]')

    # update stats
    curr_turn += 1
    curr_player = 'Red' if curr_player == 'Yellow' else 'Yellow'
    game_history.append(move_chosen)
# Out:
# ==================================================
# Turn #1 | Red ==> Move 3 [4.214s]
# Turn #2 | Yellow ==> Move 1 [3.501s]
# Turn #3 | Red ==> Move 5 [3.387s]
# Turn #4 | Yellow ==> Move 1 [2.707s]
# Turn #5 | Red ==> Move 5 [2.749s]
# Turn #6 | Yellow ==> Move 6 [3.248s]
# Turn #7 | Red ==> Move 1 [2.3s]
# Turn #8 | Yellow ==> Move 3 [3.424s]
# Turn #9 | Red ==> Move 1 [2.339s]
# Turn #10 | Yellow ==> Move 2 [2.643s]
# Turn #11 | Red ==> Move 3 [1.45s]
# Turn #12 | Yellow ==> Move 6 [1.121s]
# Turn #13 | Red ==> Move 5 [0.913s]
# Turn #14 | Yellow ==> Move 5 [1.211s]
# Turn #15 | Red ==> Move 2 [1.505s]
# Turn #16 | Yellow ==> Move 6 [1.748s]
# Turn #17 | Red ==> Move 6 [0.937s]
# Turn #18 | Yellow ==> Move 5 [1.153s]
# Turn #19 | Red ==> Move 5 [2.009s]
# Turn #20 | Yellow ==> Move 6 [1.565s]
# Turn #21 | Red ==> Move 4 [0.57s]
# Turn #22 | Yellow ==> Move 4 [1.098s]
# Turn #23 | Red ==> Move 4 [0.66s]
# Turn #24 | Yellow ==> Move 2 [1.303s]
# Turn #25 | Red ==> Move 0 [0.455s]
# Turn #26 | Yellow ==> Move 4 [1.322s]
# Turn #27 | Red ==> Move 6 [1.039s]
# Turn #28 | Yellow ==> Move 4 [0.686s]
# Turn #29 | Red ==> Move 0 [0.228s]
# Turn #30 | Yellow ==> Move 3 [0.091s]

# %% [markdown]
# ### Viewing the Game

# %%
# Load history into GUI
gui.load_history(game_history)

# Starting GUI loop
gui.root.mainloop()

# %%
# don't forget to crown the winner
tree_1.decide_winner()

# %%
# looking at our resulting data
for i in range(len(tree_1.memory_bank)):
    curr_player = 'Red' if i % 2 == 0 else 'Yellow'
    print(f'Turn #{i+1} for {curr_player} ==> {tree_1.memory_bank[i][1]}\t{tree_1.memory_bank[i][2]}')
# Out:
# Turn #1 for Red ==> [0.075, 0.075, 0.115, 0.115, 0.075, 0.44, 0.105]	1
# Turn #2 for Yellow ==> [0.095, 0.1, 0.08, 0.235, 0.155, 0.21, 0.125]	-1
# Turn #3 for Red ==> [0.07, 0.075, 0.095, 0.455, 0.085, 0.17, 0.05]	1
# Turn #4 for Yellow ==> [0.095, 0.04, 0.095, 0.51, 0.075, 0.075, 0.11]	-1
# Turn #5 for Red ==> [0.095, 0.045, 0.085, 0.4, 0.215, 0.065, 0.095]	1
# Turn #6 for Yellow ==> [0.08, 0.055, 0.1, 0.315, 0.105, 0.19, 0.155]	-1
# Turn #7 for Red ==> [0.06, 0.03, 0.08, 0.37, 0.36, 0.05, 0.05]	1
# Turn #8 for Yellow ==> [0.055, 0.24, 0.15, 0.195, 0.085, 0.155, 0.12]	-1
# Turn #9 for Red ==> [0.08, 0.16, 0.1, 0.075, 0.45, 0.065, 0.07]	1
# Turn #10 for Yellow ==> [0.04, 0.04, 0.515, 0.065, 0.06, 0.175, 0.105]	-1
# Turn #11 for Red ==> [0.06, 0.035, 0.085, 0.575, 0.085, 0.09, 0.07]	1
# Turn #12 for Yellow ==> [0.05, 0.015, 0.205, 0.065, 0.03, 0.115, 0.52]	-1
# Turn #13 for Red ==> [0.055, 0.035, 0.085, 0.105, 0.075, 0.605, 0.04]	1
# Turn #14 for Yellow ==> [0.08, 0.045, 0.095, 0.065, 0.05, 0.565, 0.1]	-1
# Turn #15 for Red ==> [0.06, 0.075, 0.235, 0.21, 0.145, 0.11, 0.165]	1
# Turn #16 for Yellow ==> [0.075, 0.01, 0.11, 0.045, 0.025, 0.075, 0.66]	-1
# Turn #17 for Red ==> [0.065, 0.02, 0.105, 0.095, 0.055, 0.025, 0.635]	1
# Turn #18 for Yellow ==> [0.12, 0.03, 0.15, 0.14, 0.035, 0.355, 0.17]	-1
# Turn #19 for Red ==> [0.065, 0.02, 0.055, 0.12, 0.03, 0.435, 0.275]	1
# Turn #20 for Yellow ==> [0.105, 0.035, 0.085, 0.14, 0.03, 0, 0.605]	-1
# Turn #21 for Red ==> [0.09, 0.04, 0.1, 0.165, 0.485, 0, 0.12]	1
# Turn #22 for Yellow ==> [0.065, 0.05, 0.075, 0.1, 0.66, 0, 0.05]	-1
# Turn #23 for Red ==> [0.17, 0.035, 0.16, 0.13, 0.42, 0, 0.085]	1
# Turn #24 for Yellow ==> [0.04, 0.02, 0.805, 0.085, 0.02, 0, 0.03]	-1
# Turn #25 for Red ==> [0.405, 0.02, 0.205, 0.145, 0.105, 0, 0.12]	1
# Turn #26 for Yellow ==> [0.025, 0.01, 0.185, 0.18, 0.515, 0, 0.085]	-1
# Turn #27 for Red ==> [0.14, 0.035, 0.225, 0.155, 0.265, 0, 0.18]	1
# Turn #28 for Yellow ==> [0.02, 0.03, 0.065, 0.29, 0.595, 0, 0]	-1
# Turn #29 for Red ==> [0.39, 0.08, 0.16, 0.19, 0.18, 0, 0]	1
# Turn #30 for Yellow ==> [0.01, 0.08, 0.19, 0.675, 0.045, 0, 0]	-1
